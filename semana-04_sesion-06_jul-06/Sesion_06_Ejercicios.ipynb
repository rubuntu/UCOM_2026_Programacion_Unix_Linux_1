# %% [markdown]
# # Ejercicios Prácticos - Sesión 06
# ## Programación Unix/Linux 1: Scripts y Automatización
#
# Este anotador contiene los ejercicios de práctica correspondientes a la **Sesión 06** sobre **Scripts y Automatización**.
# Por favor, completa cada ejercicio siguiendo las instrucciones detalladas. Asegúrate de probar y ejecutar tus celdas de código para verificar que funcionan correctamente.
#
# ---

# %% [markdown]
# ### **Ejercicio 1: Operaciones Aritméticas y Variables en Bash**
#
# **Objetivo:** Familiarizarse con la declaración de variables y la ejecución de operaciones matemáticas básicas en Bash.
#
# **Instrucciones:**
# 1. Define dos variables numéricas, `A` y `B`, con los valores `20` y `6` respectivamente.
# 2. Calcula e imprime en pantalla:
#    - La suma de `A` y `B`.
#    - La resta de `A` y `B`.
#    - El producto de `A` y `B`.
#    - La división entera de `A` entre `B`.
#    - El residuo (módulo) de la división de `A` entre `B`.
# 3. Formatea la salida para que sea clara y legible para el usuario.
#
# *Pista:* Utiliza la sintaxis `$(( operacion ))` para realizar la aritmética en Bash.

# %%
%%bash
# --- Escribe tu solución aquí ---

# %% [markdown]
# ### **Ejercicio 2: Verificación de Archivos y Condicionales**
#
# **Objetivo:** Utilizar estructuras condicionales (`if-else`) para verificar el estado de archivos y directorios.
#
# **Instrucciones:**
# 1. Define una variable `directorio` con el valor `"mi_respaldo"`.
# 2. Escribe un script en Bash que verifique si existe ese directorio en la ubicación actual.
# 3. Si el directorio **existe**, debe imprimir: `"El directorio 'mi_respaldo' ya existe."`, y listar su contenido con `ls -la`.
# 4. Si el directorio **no existe**, debe:
#    - Imprimir: `"El directorio 'mi_respaldo' no existe. Creándolo..."`.
#    - Crear el directorio.
#    - Crear un archivo vacío dentro de él llamado `archivo_inicial.txt`.
#    - Imprimir: `"Directorio y archivo inicial creados con éxito."`.
#
# *Pista:* Utiliza el operador `[ -d "$directorio" ]` para verificar la existencia del directorio.

# %%
%%bash
# --- Escribe tu solución aquí ---

# %% [markdown]
# ### **Ejercicio 3: Bucles y Redirección de Entrada/Salida**
#
# **Objetivo:** Implementar bucles (`for` o `while`) combinados con redirección de salida (`>` y `>>`).
#
# **Instrucciones:**
# 1. Crea un script en Bash que recorra los números del `1` al `20` utilizando un bucle.
# 2. Para cada número:
#    - Evalúa si el número es par o impar.
#    - Si es **par**, agrégalo al final de un archivo llamado `pares.txt`.
#    - Si es **impar**, agrégalo al final de un archivo llamado `impares.txt`.
# 3. Antes de ejecutar el bucle, asegúrate de limpiar o eliminar los archivos `pares.txt` e `impares.txt` si ya existen, para evitar acumular resultados de ejecuciones anteriores.
# 4. Al finalizar el bucle, muestra en consola el contenido de ambos archivos con un encabezado descriptivo.

# %%
%%bash
# --- Escribe tu solución aquí ---

# %% [markdown]
# ### **Ejercicio 4: Scripting en Python para Automatización de Archivos**
#
# **Objetivo:** Desarrollar un script en Python que manipule archivos e información de forma automatizada.
#
# **Instrucciones:**
# 1. Crea un archivo CSV de prueba llamado `calificaciones.csv` desde tu script o usando redirección, que contenga el nombre y la nota de 5 alumnos. Ejemplo:
#    ```csv
#    Nombre,Nota
#    Luis,85
#    Sofia,92
#    Pedro,58
#    Maria,74
#    Juan,45
#    ```
# 2. Escribe un script en Python que lea este archivo `calificaciones.csv`.
# 3. Clasifique a cada alumno en función de su nota:
#    - Si la nota es **menor a 60**, la clasificación es `"Reprobado"`.
#    - Si es **60 o mayor**, la clasificación es `"Aprobado"`.
# 4. Escribe un nuevo archivo llamado `resultado_final.txt` que contenga un reporte formateado con los resultados. Ejemplo:
#    ```
#    === REPORTE DE CALIFICACIONES ===
#    Luis: Aprobado (Nota: 85)
#    Sofia: Aprobado (Nota: 92)
#    Pedro: Reprobado (Nota: 58)
#    ...
#    ```
# 5. Imprime en consola el contenido del reporte generado.

# %%
# --- Escribe tu solución aquí ---

# %% [markdown]
# ### **Ejercicio 5: Configuración Declarativa con Ansible (Teórico/Práctico)**
#
# **Objetivo:** Entender la estructura de los Playbooks de Ansible y el concepto de infraestructura como código.
#
# **Instrucciones:**
# Escribe un Playbook de Ansible en formato YAML que realice las siguientes tareas de configuración en un grupo de servidores llamado `servidores_web`:
# 1. Instale el servidor web `nginx` utilizando el gestor de paquetes apropiado (por ejemplo, `apt` para Debian/Ubuntu).
# 2. Copie un archivo local `/home/usuario/index.html` al directorio de destino del servidor web `/var/www/html/index.html`.
# 3. Asegure que el servicio de `nginx` esté iniciado (`started`) y habilitado para ejecutarse en el arranque del sistema (`enabled: yes`).
#
# *Nota:* Escribe el código del playbook en la celda de texto (Markdown) o de código (como texto plano) a continuación. Explica brevemente el propósito de cada uno de los módulos utilizados (`apt`, `copy`, `service`).

# %% [markdown]
# #### **Escribe tu Playbook de Ansible y la explicación aquí:**
#
# ```yaml
# # --- Tu Playbook de Ansible ---
# ```
#
# **Explicación de los módulos:**
# - **Módulo apt:** ...
# - **Módulo copy:** ...
# - **Módulo service:** ...
